# %%
import torchvision.datasets as dataset

# %%
dataset.CelebA(root="./dataset", split="all", download=True)
# Out:
# Using downloaded and verified file: ./dataset/celeba/img_align_celeba.zip
# 0it [00:00, ?it/s]
# Using downloaded and verified file: ./dataset/celeba/identity_CelebA.txt
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2196/2205399439.py in <module>
# ----> 1 dataset.CelebA(root="./dataset", split="all", download=True)
#
# /usr/local/lib/python3.8/dist-packages/torchvision/datasets/celeba.py in __init__(self, root, split, target_type, transform, target_transform, download)
#      75
#      76         if download:
# ---> 77             self.download()
#      78
#      79         if not self._check_integrity():
#
# /usr/local/lib/python3.8/dist-packages/torchvision/datasets/celeba.py in download(self)
#     130
# ...

# %%
import glob
import numpy as np
import shutil

# %%
imgs = glob.glob('../../share_dataset/six_objects/stimuli_objects/idle/*')

# %%
print(len(imgs))
idx = np.arange(0,len(imgs))
np.random.shuffle(idx)
# Out:
# 1300

# %%
len(idx[:1000])
# Out:
# 1000

# %%
desc = './idles/'
count = 21
for index in range(1000-20):
    src_path = imgs[0]
    # file_ext = src_path.split('.')[2]
    desc_path = f'{desc}{count}.jpg'
    print(src_path,desc_path)
    shutil.copy(src_path, desc_path)
    count = count + 1
    # break
# Out:
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/21.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/22.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/23.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/24.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/25.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/26.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/27.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/28.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/29.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/30.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/31.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/32.jpg
# ../../share_dataset/six_objects/stimuli_objects/idle/1.jpg ./idles/33.jpg
# ...
